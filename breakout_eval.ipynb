# %%
import numpy as np

data = np.load('/home/sequenzia/dev/repos/atari-rl/agents/ppo/ALE-Breakout-v5_1/evaluations.npz')


lst = data.files

for idx in range(len(data['timesteps'])):
    
    timestamp = data['timesteps'][idx]
    results = data['results'][idx]
    
    print(f'{timestamp}: {results.mean()} | {results.std()}')
# Out:
# 100000: 31.2 | 7.959899496852959
# 200000: 33.0 | 12.312595177297109
# 300000: 40.2 | 10.514751542475931
# 400000: 35.4 | 13.937001112147477
# 500000: 33.0 | 12.521980673998822

# %%
data = np.load('/home/sequenzia/breakout_backup/PPO/ALE-Breakout-v5_1/evaluations.npz')

lst = data.files

for idx in range(len(data['timesteps'])):
    
    timestamp = data['timesteps'][idx]
    results = data['results'][idx]
    
    print(f'{timestamp}: {results.mean()} | {results.std()}')

# for item in lst:

#     if item == 'results': 
#         print(data[item][0])
    

    # if item == 'results':
    #     print(data[item])
# Out:
# 100000: 11.8 | 2.315167380558045
# 200000: 13.6 | 4.2708313008125245
# 300000: 20.2 | 1.9390719429665317
# 400000: 18.8 | 5.075431016179808
# 500000: 13.4 | 3.555277766926235
# 600000: 17.6 | 6.374950980203692
# 700000: 17.2 | 7.025667228100119
# 800000: 16.2 | 5.075431016179809
# 900000: 23.4 | 7.605261336732617
# 1000000: 17.8 | 4.166533331199932
# 1100000: 16.6 | 4.715930449020639
# 1200000: 19.0 | 3.286335345030997
# 1300000: 20.0 | 5.291502622129181
# 1400000: 18.4 | 10.05186549850325
# 1500000: 16.4 | 6.7111846942250075
# 1600000: 24.8 | 7.547184905645284
# 1700000: 17.6 | 4.029888335921977
# 1800000: 20.2 | 7.626270385975047
# 1900000: 21.6 | 11.482160075525858
# 2000000: 17.8 | 5.30659966456864
# 2100000: 19.6 | 6.248199740725324
# 2200000: 20.0 | 8.07465169527454
# 2300000: 23.8 | 9.453041838477178
# 2400000: 19.2 | 11.822013364905319
# 2500000: 22.0 | 7.874007874011811
# 2600000: 25.0 | 4.857983120596447
# 2700000: 26.6 | 12.955307792561317
# ...
